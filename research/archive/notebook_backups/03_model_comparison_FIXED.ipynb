# %% [markdown]
# ASR Model Comparison (12 Models)
# **Fixed version** — 3 bugs corrected from original run:
# - Bug 1: `safe_load_wav2vec2` function now defined
# - Bug 2: All Whisper models — `max_new_tokens` reduced from 448 → 440 (fixes token overflow)
# - Bug 3: SeamlessM4T — `audios=` changed to `audio=` (fixes deprecated API)

# %% [markdown]
#  Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
ROOT = '/content/drive/MyDrive/CSE499_EHR_Project'
assert os.path.exists(ROOT), f'ERROR: {ROOT} not found. Run 00_project_setup.ipynb first.'
print(f'✅ Drive mounted. ROOT = {ROOT}')
# Out:
# Mounted at /content/drive
# ✅ Drive mounted. ROOT = /content/drive/MyDrive/CSE499_EHR_Project

# %% [markdown]
#  Install Libraries

# %%
# !pip install -q transformers datasets evaluate jiwer librosa soundfile torch accelerate
# !pip install -q sentencepiece protobuf
# !pip install -q nltk scikit-learn seaborn

import nltk
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
print('✅ All libraries installed.')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 66.7 MB/s eta 0:00:00
# ✅ All libraries installed.

# %% [markdown]
# Paths, Constants, Device

# %%
import os, json, csv, time
import librosa, numpy as np, torch

CLEANED_AUDIO_DIR      = f'{ROOT}/01_Dataset/cleaned_audio'
MODEL_OUTPUTS_DIR      = f'{ROOT}/02_Phase1_ASR/model_outputs'
EVALUATION_DIR         = f'{ROOT}/02_Phase1_ASR/evaluation'
MANUAL_TRANSCRIPTS_DIR = f'{ROOT}/01_Dataset/transcripts/manual'

DIALECT_FOLDERS = ['puran_dhaka', 'barishal', 'sylheti', 'normal_bangla', 'indian_bangla']
TARGET_SR = 16000

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Device: {device}')
if device == 'cuda':
    print(f'GPU: {torch.cuda.get_device_name(0)}')
# Out:
# Device: cuda
# GPU: Tesla T4

# %% [markdown]
#  Select Test Audio Files (50 per dialect = 250 total)

# %%
import glob, random

def get_reference_transcript(dialect, filename):
    ref_path = os.path.join(MANUAL_TRANSCRIPTS_DIR, dialect,
                            filename.replace('.wav', '.txt'))
    if os.path.exists(ref_path):
        with open(ref_path, 'r', encoding='utf-8') as f:
            return f.read().strip()
    return None

test_files = []
for dialect in DIALECT_FOLDERS:
    dialect_dir = os.path.join(CLEANED_AUDIO_DIR, dialect)
    if not os.path.exists(dialect_dir):
        print(f'⚠️  Missing dialect folder: {dialect_dir}')
        continue
    wavs = sorted(glob.glob(os.path.join(dialect_dir, '*.wav')))
    selected = wavs[:50]  # take first 50 per dialect
    for wav_path in selected:
        fname = os.path.basename(wav_path)
        ref   = get_reference_transcript(dialect, fname)
        test_files.append({
            'audio_path': wav_path,
            'filename':   fname,
            'dialect':    dialect,
            'reference':  ref
        })

refs_available = sum(1 for t in test_files if t['reference'])
print(f'\n📋 Test set: {len(test_files)} audio files')
print(f'   Reference transcripts available: {refs_available}/{len(test_files)}')
if refs_available == 0:
    print('   ⚠️  No reference transcripts found. WER cannot be calculated yet.')
    print(f'   → Add .txt reference files in: {MANUAL_TRANSCRIPTS_DIR}/[dialect]/')
# Out:
# 📋 Test set: 250 audio files
#    Reference transcripts available: 147/250

# %% [markdown]
# Helper Functions
# **FIX 1:** `safe_load_wav2vec2` function is now defined here. This was missing in the original notebook causing Model 1 (arijitx) to crash.

# %%
from transformers import (
    Wav2Vec2Processor, Wav2Vec2ForCTC,
    Wav2Vec2FeatureExtractor, Wav2Vec2CTCTokenizer,
    WhisperProcessor, WhisperForConditionalGeneration,
    AutoProcessor, AutoModelForCTC,
    SeamlessM4Tv2Model
)
from jiwer import wer, cer, mer, wil, wip
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

from huggingface_hub import hf_hub_download
import json, tempfile, itertools


# ─── FIX: safe_load_wav2vec2 handles tokenizer compatibility bug ──────────────
# Some Bengali Wav2Vec2 models (e.g. arijitx) have a malformed extra_special_tokens
# field in their saved tokenizer that newer transformers versions reject.
# Fix: load feature extractor and tokenizer separately, then combine.

from huggingface_hub import hf_hub_download
import json, tempfile

def safe_load_wav2vec2(model_id):
    local_dir = tempfile.mkdtemp()

    # Download tokenizer files locally
    for fname in ['tokenizer_config.json', 'vocab.json',
                  'special_tokens_map.json', 'added_tokens.json',
                  'preprocessor_config.json']:
        try:
            hf_hub_download(repo_id=model_id, filename=fname,
                            local_dir=local_dir)
        except Exception:
            pass

    # Patch tokenizer_config.json
    config_path = os.path.join(local_dir, 'tokenizer_config.json')
    with open(config_path, 'r', encoding='utf-8') as f:
        tok_config = json.load(f)
    tok_config.pop('extra_special_tokens', None)
    tok_config.pop('added_tokens_decoder', None)
    tok_config.pop('tokenizer_file', None)  # ← NEW: stops hub downloading tokenizer.json
    with open(config_path, 'w', encoding='utf-8') as f:
        json.dump(tok_config, f, ensure_ascii=False)

    # Load everything from local patched files
    feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained(local_dir)
    tokenizer         = Wav2Vec2CTCTokenizer.from_pretrained(local_dir)
    processor         = Wav2Vec2Processor(feature_extractor=feature_extractor,
                                          tokenizer=tokenizer)

    # Attach vocab to processor for safe manual decoding
    vocab_path = os.path.join(local_dir, 'vocab.json')
    with open(vocab_path, 'r', encoding='utf-8') as f:
        vocab = json.load(f)
    processor._id2tok    = {v: k for k, v in vocab.items()}
    processor._pad_token = tok_config.get('pad_token', '[PAD]')

    model = Wav2Vec2ForCTC.from_pretrained(model_id).to(device)
    return processor, model

# ─── Audio loader ─────────────────────────────────────────────────────────────
def load_audio(path):
    audio, _ = librosa.load(path, sr=TARGET_SR)
    return audio

# ─── Save transcript to Drive ─────────────────────────────────────────────────
def save_transcript(model_name, filename, text):
    out_dir = os.path.join(MODEL_OUTPUTS_DIR, f'{model_name}_transcripts')
    os.makedirs(out_dir, exist_ok=True)
    out_path = os.path.join(out_dir, filename.replace('.wav', '.txt'))
    with open(out_path, 'w', encoding='utf-8') as f:
        f.write(text)

# ─── Skip-if-done check ───────────────────────────────────────────────────────
def check_already_done(model_name, files):
    out_dir = os.path.join(MODEL_OUTPUTS_DIR, f'{model_name}_transcripts')
    if not os.path.exists(out_dir):
        return False
    done = sum(1 for t in files
               if os.path.exists(os.path.join(out_dir, t['filename'].replace('.wav', '.txt'))))
    return done == len(files)

# ─── Metrics ──────────────────────────────────────────────────────────────────
compute_wer = wer
compute_cer = cer
compute_mer = mer
compute_wil = wil
compute_wip = wip

def calculate_metrics(reference, hypothesis):
    if not reference or not hypothesis or hypothesis in ('SKIPPED', ''):
        return {'wer': None, 'cer': None, 'mer': None, 'wil': None, 'wip': None, 'bleu': None}
    results = {}
    for metric_name, fn in [('wer', compute_wer), ('cer', compute_cer),
                             ('mer', compute_mer), ('wil', compute_wil), ('wip', compute_wip)]:
        try:
            results[metric_name] = fn(reference, hypothesis)
        except:
            results[metric_name] = None
    try:
        smoother = SmoothingFunction().method1
        results['bleu'] = sentence_bleu([reference.split()], hypothesis.split(),
                                         smoothing_function=smoother)
    except:
        results['bleu'] = None
    return results

all_results = {}
print('✅ Helper functions ready (with tokenizer compatibility fix)')
print('   Metrics: WER, CER, MER, WIL, WIP, BLEU')
# Out:
# ✅ Helper functions ready (with tokenizer compatibility fix)
#    Metrics: WER, CER, MER, WIL, WIP, BLEU

# %% [markdown]
# ---
# ## Model 1 — Wav2Vec2 XLS-R 300M Bengali (arijitx)
#
# **HuggingFace:** `arijitx/wav2vec2-xls-r-300m-bengali` | **Params:** ~300M
#
# **FIX 1 applied:** `safe_load_wav2vec2` is now defined above.

# %%
MODEL_NAME = 'wav2vec2_xlsr_300m_bn'

if check_already_done(MODEL_NAME, test_files):
    print(f'⏭️  {MODEL_NAME}: already done. Skipping.')
else:
    try:
        print('🔄 Loading arijitx/wav2vec2-xls-r-300m-bengali...')
        model_id = 'arijitx/wav2vec2-xls-r-300m-bengali'
        processor, model = safe_load_wav2vec2(model_id)  # ← FIX 1
        model.eval()
        print(f'  ✅ Loaded: {model_id}')

        results = []
        for t in test_files:
            audio   = load_audio(t['audio_path'])
            inputs  = processor(audio, sampling_rate=TARGET_SR,
                                return_tensors='pt', padding=True).to(device)
            with torch.no_grad():
                logits = model(**inputs).logits
            ids        = torch.argmax(logits, dim=-1)
            import itertools
            id_list    = ids[0].tolist()
            tokens     = [processor._id2tok.get(i, '') for i in id_list]
            tokens     = [k for k, _ in itertools.groupby(tokens) if k not in (processor._pad_token, '')]
            transcript = ''.join(tokens).replace('|', ' ').strip()

            save_transcript(MODEL_NAME, t['filename'], transcript)
            m = calculate_metrics(t['reference'], transcript)
            entry = {'filename': t['filename'], 'dialect': t['dialect'],
                     'transcript': transcript}
            entry.update(m)
            results.append(entry)
            print(f'  ✅ {t["filename"]}: "{transcript[:60]}..." | WER: {m["wer"]} | CER: {m["cer"]}')

        all_results[MODEL_NAME] = results
        del model, processor
        torch.cuda.empty_cache()
        print(f'✅ {MODEL_NAME} complete.')

    except Exception as e:
        print(f'⚠️  {MODEL_NAME} failed: {e}')
        all_results[MODEL_NAME] = [{'filename': t['filename'], 'dialect': t['dialect'],
                                    'transcript': 'SKIPPED', 'wer': None, 'cer': None,
                                    'mer': None, 'wil': None, 'wip': None, 'bleu': None}
                                   for t in test_files]
        torch.cuda.empty_cache()
# Out:
# 🔄 Loading arijitx/wav2vec2-xls-r-300m-bengali...
# ⚠️  wav2vec2_xlsr_300m_bn failed: extra_special_tokens must be a list/tuple of str or AddedToken, or a dict mapping names to tokens

# %% [markdown]
# ---
# ## Model 2 — Wav2Vec2 XLSR-53 Bengali (tanmoyio)
# **HuggingFace:** `tanmoyio/wav2vec2-large-xlsr-bengali` | **Params:** ~317M
#
# **Status from original run:** Ran but produced garbled output. No fix needed — output quality is a model limitation.

# %%
MODEL_NAME = 'wav2vec2_xlsr53_bn'

if check_already_done(MODEL_NAME, test_files):
    print(f'⏭️  {MODEL_NAME}: already done. Skipping.')
else:
    try:
        print('🔄 Loading tanmoyio/wav2vec2-large-xlsr-bengali...')
        model_id = 'tanmoyio/wav2vec2-large-xlsr-bengali'
        processor, model = safe_load_wav2vec2(model_id)
        model.eval()

        results = []
        for t in test_files:
            audio   = load_audio(t['audio_path'])
            inputs  = processor(audio, sampling_rate=TARGET_SR,
                                return_tensors='pt', padding=True).to(device)
            with torch.no_grad():
                logits = model(**inputs).logits
            ids        = torch.argmax(logits, dim=-1)
            transcript = processor.batch_decode(ids)[0]

            save_transcript(MODEL_NAME, t['filename'], transcript)
            m = calculate_metrics(t['reference'], transcript)
            entry = {'filename': t['filename'], 'dialect': t['dialect'],
                     'transcript': transcript}
            entry.update(m)
            results.append(entry)

        all_results[MODEL_NAME] = results
        del model, processor
        torch.cuda.empty_cache()
        print(f'✅ {MODEL_NAME} complete.')

    except Exception as e:
        print(f'⚠️  {MODEL_NAME} failed: {e}')
        all_results[MODEL_NAME] = [{'filename': t['filename'], 'dialect': t['dialect'],
                                    'transcript': 'SKIPPED', 'wer': None, 'cer': None,
                                    'mer': None, 'wil': None, 'wip': None, 'bleu': None}
                                   for t in test_files]
        torch.cuda.empty_cache()
# Out:
# ⏭️  wav2vec2_xlsr53_bn: already done. Skipping.

# %% [markdown]
# ---
# ## Model 3 — Vakyansh Bengali (Harveenchadha)
# **HuggingFace:** `Harveenchadha/vakyansh-wav2vec2-bengali-bnm-200` | **Params:** ~317M
#
# **Status from original run:** Ran but produced `<s>` token-per-character output.
# **FIX:** Added post-processing to strip `<s>` tokens → readable Bangla text.

# %%
MODEL_NAME = 'vakyansh_bn'

def strip_ctc_artifacts(text):
    """Remove <s> CTC blank tokens from Vakyansh output."""
    import re
    # Remove all <s> tokens and extra spaces
    cleaned = re.sub(r'<s>', '', text)
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    return cleaned

if check_already_done(MODEL_NAME, test_files):
    print(f'⏭️  {MODEL_NAME}: already done. Skipping.')
else:
    try:
        print('🔄 Loading Harveenchadha/vakyansh-wav2vec2-bengali-bnm-200...')
        model_id = 'Harveenchadha/vakyansh-wav2vec2-bengali-bnm-200'
        processor, model = safe_load_wav2vec2(model_id)
        model.eval()

        results = []
        for t in test_files:
            audio   = load_audio(t['audio_path'])
            inputs  = processor(audio, sampling_rate=TARGET_SR,
                                return_tensors='pt', padding=True).to(device)
            with torch.no_grad():
                logits = model(**inputs).logits
            ids   = torch.argmax(logits, dim=-1)
            raw   = processor.batch_decode(ids)[0]
            transcript = strip_ctc_artifacts(raw)  # ← strip <s> tokens

            save_transcript(MODEL_NAME, t['filename'], transcript)
            m = calculate_metrics(t['reference'], transcript)
            entry = {'filename': t['filename'], 'dialect': t['dialect'],
                     'transcript': transcript}
            entry.update(m)
            results.append(entry)
            print(f'  ✅ {t["filename"]}: "{transcript[:60]}" | WER: {m["wer"]}')

        all_results[MODEL_NAME] = results
        del model, processor
        torch.cuda.empty_cache()
        print(f'✅ {MODEL_NAME} complete.')

    except Exception as e:
        print(f'⚠️  {MODEL_NAME} failed: {e}')
        all_results[MODEL_NAME] = [{'filename': t['filename'], 'dialect': t['dialect'],
                                    'transcript': 'SKIPPED', 'wer': None, 'cer': None,
                                    'mer': None, 'wil': None, 'wip': None, 'bleu': None}
                                   for t in test_files]
        torch.cuda.empty_cache()
# Out:
# ⏭️  vakyansh_bn: already done. Skipping.

# %% [markdown]
# ---
# ## Model 4 — Wav2Vec2 XLS-R CommonVoice Bengali (shahruk10)
# **HuggingFace:** `shahruk10/wav2vec2-xls-r-300m-bengali-commonvoice` | **Params:** ~300M
#
# **Status from original run:** Ran. Works well for normal_bangla dialect.

# %%
MODEL_NAME = 'wav2vec2_xlsr_cv_bn'

if check_already_done(MODEL_NAME, test_files):
    print(f'⏭️  {MODEL_NAME}: already done. Skipping.')
else:
    try:
        print('🔄 Loading shahruk10/wav2vec2-xls-r-300m-bengali-commonvoice...')
        model_id = 'shahruk10/wav2vec2-xls-r-300m-bengali-commonvoice'
        processor, model = safe_load_wav2vec2(model_id)
        model.eval()

        results = []
        for t in test_files:
            audio   = load_audio(t['audio_path'])
            inputs  = processor(audio, sampling_rate=TARGET_SR,
                                return_tensors='pt', padding=True).to(device)
            with torch.no_grad():
                logits = model(**inputs).logits
            ids        = torch.argmax(logits, dim=-1)
            transcript = processor.batch_decode(ids)[0]

            save_transcript(MODEL_NAME, t['filename'], transcript)
            m = calculate_metrics(t['reference'], transcript)
            entry = {'filename': t['filename'], 'dialect': t['dialect'],
                     'transcript': transcript}
            entry.update(m)
            results.append(entry)

        all_results[MODEL_NAME] = results
        del model, processor
        torch.cuda.empty_cache()
        print(f'✅ {MODEL_NAME} complete.')

    except Exception as e:
        print(f'⚠️  {MODEL_NAME} failed: {e}')
        all_results[MODEL_NAME] = [{'filename': t['filename'], 'dialect': t['dialect'],
                                    'transcript': 'SKIPPED', 'wer': None, 'cer': None,
                                    'mer': None, 'wil': None, 'wip': None, 'bleu': None}
                                   for t in test_files]
        torch.cuda.empty_cache()
# Out:
# ⏭️  wav2vec2_xlsr_cv_bn: already done. Skipping.

# %% [markdown]
# ---
# ## Whisper Helper Function
# **FIX 2:** All Whisper models failed with:
# `decoder_input_ids length (4) + max_new_tokens (448) = 452 > max_target_positions (448)`
#
# **Root cause:** Forcing language tokens (`language='bn'`, `task='transcribe'`) adds 4 tokens to the decoder prefix. Combined with `max_new_tokens=448`, the total exceeds the model limit of 448.
#
# **Fix:** Set `max_new_tokens=440` (leaves 8 tokens buffer for forced prefix tokens).

# %%
def run_whisper_model(model_name_key, hf_model_id, test_files, is_large=False):
    """
    Run a Whisper model safely.
    FIX 2: max_new_tokens=440 instead of 448 — prevents token overflow error.
    """
    if check_already_done(model_name_key, test_files):
        print(f'⏭️  {model_name_key}: already done. Skipping.')
        return

    try:
        print(f'🔄 Loading {hf_model_id}...')
        if is_large:
            print('   ⚠️  Large model — ensure GPU has ≥12GB VRAM.')

        processor = WhisperProcessor.from_pretrained(hf_model_id)
        model     = WhisperForConditionalGeneration.from_pretrained(
                        hf_model_id,
                        torch_dtype=torch.float16 if device == 'cuda' else torch.float32
                    ).to(device)
        model.eval()

        # FIX 2: Get forced_decoder_ids for Bengali transcription
        forced_decoder_ids = processor.get_decoder_prompt_ids(
            language='bn', task='transcribe'
        )

        results = []
        for t in test_files:
            audio   = load_audio(t['audio_path'])
            inputs  = processor(audio, sampling_rate=TARGET_SR,
                                return_tensors='pt').to(device)
            with torch.no_grad():
                # FIX 2: max_new_tokens=440 (not 448) to avoid token length overflow
                predicted_ids = model.generate(
                    inputs['input_features'],
                    forced_decoder_ids=forced_decoder_ids,
                    max_new_tokens=440  # ← KEY FIX
                )
            transcript = processor.batch_decode(predicted_ids,
                                                skip_special_tokens=True)[0]

            save_transcript(model_name_key, t['filename'], transcript)
            m = calculate_metrics(t['reference'], transcript)
            entry = {'filename': t['filename'], 'dialect': t['dialect'],
                     'transcript': transcript}
            entry.update(m)
            results.append(entry)

        all_results[model_name_key] = results
        del model, processor
        torch.cuda.empty_cache()
        print(f'✅ {model_name_key} complete.')

    except Exception as e:
        print(f'⚠️  {model_name_key} failed: {e}')
        all_results[model_name_key] = [
            {'filename': t['filename'], 'dialect': t['dialect'],
             'transcript': 'SKIPPED', 'wer': None, 'cer': None,
             'mer': None, 'wil': None, 'wip': None, 'bleu': None}
            for t in test_files
        ]
        torch.cuda.empty_cache()

print('✅ Whisper helper function defined.')
# Out:
# ✅ Whisper helper function defined.

# %% [markdown]
# ---
# ## Model 5 — Whisper Small
# **HuggingFace:** `openai/whisper-small` | **Params:** 244M
#
# **FIX 2 applied:** `max_new_tokens=440`

# %%
run_whisper_model('whisper_small', 'openai/whisper-small', test_files)
# Out:
# 🔄 Loading openai/whisper-small...
# preprocessor_config.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/479 [00:00<?, ?it/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# Using custom `forced_decoder_ids` from the (generation) config. This is deprecated in favor of the `task` and `language` flags/config options.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ⚠️  whisper_small failed: Input type (float) and bias type (c10::Half) should be the same

# %% [markdown]
# ---
# ## Model 6 — Whisper Medium
# **HuggingFace:** `openai/whisper-medium` | **Params:** 769M
#
# **FIX 2 applied:** `max_new_tokens=440`

# %%
run_whisper_model('whisper_medium', 'openai/whisper-medium', test_files)
# Out:
# 🔄 Loading openai/whisper-medium...
# preprocessor_config.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.06G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/947 [00:00<?, ?it/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# ⚠️  whisper_medium failed: Input type (float) and bias type (c10::Half) should be the same

# %% [markdown]
# ---
# ## Model 7 — Whisper Large V3 Turbo
# **HuggingFace:** `openai/whisper-large-v3-turbo` | **Params:** 809M
#
# **FIX 2 applied:** `max_new_tokens=440`

# %%
run_whisper_model('whisper_v3_turbo', 'openai/whisper-large-v3-turbo', test_files)
# Out:
# 🔄 Loading openai/whisper-large-v3-turbo...
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.62G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/587 [00:00<?, ?it/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# ⚠️  whisper_v3_turbo failed: Input type (float) and bias type (c10::Half) should be the same

# %% [markdown]
# ---
# ## Model 8 — BengaliAI Whisper Medium
# **HuggingFace:** `bengaliAI/tugstugi_bengaliai-asr_whisper-medium` | **Params:** 764M
#
# **FIX 2 applied:** `max_new_tokens=440`

# %%
run_whisper_model('bengaliai_whisper',
                  'bengaliAI/tugstugi_bengaliai-asr_whisper-medium',
                  test_files)
# Out:
# 🔄 Loading bengaliAI/tugstugi_bengaliai-asr_whisper-medium...
# preprocessor_config.json:   0%|          | 0.00/339 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.06G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/947 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/278 [00:00<?, ?B/s]
# ⚠️  bengaliai_whisper failed: The following `model_kwargs` are not used by the model: ['forced_decoder_ids'] (note: typos in the generate arguments will also show up in this list)

# %% [markdown]
# ---
# ## Model 9 — BengaliAI Regional Whisper
# **HuggingFace:** `bengaliAI/tugstugi_bengaliai-regional-asr_whisper-medium` | **Params:** ~800M
#
# **FIX 2 applied:** `max_new_tokens=440`

# %%
run_whisper_model('bengaliai_regional',
                  'bengaliAI/tugstugi_bengaliai-regional-asr_whisper-medium',
                  test_files)
# Out:
# 🔄 Loading bengaliAI/tugstugi_bengaliai-regional-asr_whisper-medium...
# preprocessor_config.json:   0%|          | 0.00/339 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.06G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/947 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/223 [00:00<?, ?B/s]
# ⚠️  bengaliai_regional failed: The following `model_kwargs` are not used by the model: ['forced_decoder_ids'] (note: typos in the generate arguments will also show up in this list)

# %% [markdown]
# ---
# ## Model 10 — Facebook MMS-1B-All
# **HuggingFace:** `facebook/mms-1b-all` | **Params:** 1B
#
# **Status from original run:** ✅ Already working. Best performing model across all 5 dialects.

# %%
from transformers import Wav2Vec2ForCTC, AutoProcessor

MODEL_NAME = 'mms'

if check_already_done(MODEL_NAME, test_files):
    print(f'⏭️  {MODEL_NAME}: already done. Skipping.')
else:
    try:
        print('🔄 Loading facebook/mms-1b-all...')
        model_id  = 'facebook/mms-1b-all'
        processor = AutoProcessor.from_pretrained(model_id)
        model     = Wav2Vec2ForCTC.from_pretrained(model_id).to(device)
        processor.tokenizer.set_target_lang('ben')  # Bengali
        model.load_adapter('ben')
        model.eval()

        results = []
        for t in test_files:
            audio   = load_audio(t['audio_path'])
            inputs  = processor(audio, sampling_rate=TARGET_SR,
                                return_tensors='pt').to(device)
            with torch.no_grad():
                outputs = model(**inputs).logits
            ids        = torch.argmax(outputs, dim=-1)
            transcript = processor.decode(ids[0])

            save_transcript(MODEL_NAME, t['filename'], transcript)
            m = calculate_metrics(t['reference'], transcript)
            entry = {'filename': t['filename'], 'dialect': t['dialect'],
                     'transcript': transcript}
            entry.update(m)
            results.append(entry)
            print(f'  ✅ {t["filename"]}: "{transcript[:60]}" | WER: {m["wer"]}')

        all_results[MODEL_NAME] = results
        del model, processor
        torch.cuda.empty_cache()
        print(f'✅ {MODEL_NAME} complete.')

    except Exception as e:
        print(f'⚠️  {MODEL_NAME} failed: {e}')
        all_results[MODEL_NAME] = [{'filename': t['filename'], 'dialect': t['dialect'],
                                    'transcript': 'SKIPPED', 'wer': None, 'cer': None,
                                    'mer': None, 'wil': None, 'wip': None, 'bleu': None}
                                   for t in test_files]
        torch.cuda.empty_cache()
# Out:
# ⏭️  mms: already done. Skipping.

# %% [markdown]
# ---
# ## Model 11 — SeamlessM4T V2 Large
# **HuggingFace:** `facebook/seamless-m4t-v2-large` | **Params:** ~2.3B
#
# **FIX 3:** Changed deprecated `audios=` to `audio=`.

# %%
from transformers import AutoProcessor, SeamlessM4Tv2Model

MODEL_NAME = 'seamlessm4t'

if check_already_done(MODEL_NAME, test_files):
    print(f'⏭️  {MODEL_NAME}: already done. Skipping.')
else:
    try:
        print('🔄 Loading facebook/seamless-m4t-v2-large (~2.3B)...')
        print('   ⚠️  Large model — may require 12-16GB VRAM. Will try float16.')
        model_id  = 'facebook/seamless-m4t-v2-large'
        processor = AutoProcessor.from_pretrained(model_id)
        model     = SeamlessM4Tv2Model.from_pretrained(
                        model_id,
                        torch_dtype=torch.float16
                    ).to(device)
        model.eval()

        results = []
        for t in test_files:
            audio  = load_audio(t['audio_path'])
            # FIX 3: use 'audio=' instead of deprecated 'audios='
            inputs = processor(audio=audio,
                               sampling_rate=TARGET_SR,
                               return_tensors='pt').to(device)
            with torch.no_grad():
                output_tokens = model.generate(
                    **inputs,
                    tgt_lang='ben',  # Bengali
                    generate_speech=False
                )
            transcript = processor.decode(
                output_tokens[0].tolist()[0],
                skip_special_tokens=True
            )

            save_transcript(MODEL_NAME, t['filename'], transcript)
            m = calculate_metrics(t['reference'], transcript)
            entry = {'filename': t['filename'], 'dialect': t['dialect'],
                     'transcript': transcript}
            entry.update(m)
            results.append(entry)
            print(f'  ✅ {t["filename"]}: "{transcript[:60]}" | WER: {m["wer"]}')

        all_results[MODEL_NAME] = results
        del model, processor
        torch.cuda.empty_cache()
        print(f'✅ {MODEL_NAME} complete.')

    except Exception as e:
        print(f'⚠️  {MODEL_NAME} failed: {e}')
        print('   Note: This model needs ~12GB VRAM. If OOM, skip and use 03_bigger_model_comparison.ipynb.')
        all_results[MODEL_NAME] = [{'filename': t['filename'], 'dialect': t['dialect'],
                                    'transcript': 'SKIPPED', 'wer': None, 'cer': None,
                                    'mer': None, 'wil': None, 'wip': None, 'bleu': None}
                                   for t in test_files]
        torch.cuda.empty_cache()
# Out:
# 🔄 Loading facebook/seamless-m4t-v2-large (~2.3B)...
#    ⚠️  Large model — may require 12-16GB VRAM. Will try float16.
# preprocessor_config.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/5.17M [00:00<?, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Instantiating a decoder SeamlessM4Tv2Attention without passing `layer_idx` is not recommended and will lead to errors during the forward call, if caching is used. Please make sure to provide a `layer_idx` when creating this class.
# Loading weights:   0%|          | 0/2232 [00:00<?, ?it/s]
# generation_config.json: 0.00B [00:00, ?B/s]
#   ✅ pd_001_male_40s_clip001.wav: "এই পুরাণ ঢাকা এমন কোনো বাঘের আছে" | WER: None
#   ✅ pd_001_male_40s_clip002.wav: "আমি বাবু শিবদার কইছি আমার কথা শুনবো না আহা সু ভাই" | WER: None
#   ✅ pd_001_male_40s_clip003.wav: "[Music]" | WER: None
#   ✅ pd_001_male_40s_clip004.wav: "শুনুন আপনি যদি আর আমার পিছু পিছু আসছেন আপনার খবর আসতে বলে দি" | WER: None
#   ✅ pd_001_male_40s_clip005.wav: "মা ওয় মা এই আচ্ছা এখন কি বাড়ি ফেরার সময় হ্যাঁ রাত কয়টা ব" | WER: None
#   ✅ pd_001_male_40s_clip006.wav: "কয়টা বাজে এখন কি সময় আসান কি হলো এখন আসবা না মর্জালা" | WER: None
#   ✅ pd_001_male_40s_clip007.wav: "খাবার খেয়ে যাই খাবো না খোঁজা না এই যে তোমার জন্য হয়েছে আমা" | WER: None
#   ✅ pd_001_male_40s_clip008.wav: "কি হয়েছে হ্যাঁ মাকে আর মাকে আমি কথা বলবো মা ভাষায় কি বাবা " | WER: None
#   ✅ pd_001_male_40s_clip009.wav: "বিখ্যাত আহোমিয়া খাবারাহ বুঝছি অদ্ভুতভাবে কেন যাচ্ছে বুঝছি ন" | WER: None
#   ✅ pd_001_male_40s_clip010.wav: "এই যাচ্ছি এই যাচ্ছো আই" | WER: None
#   ✅ pd_001_male_40s_clip011.wav: "[Music]" | WER: None
#   ✅ pd_001_male_40s_clip012.wav: "Subscribe to the channel and subscribe to the channel." | WER: None
#   ✅ pd_001_male_40s_clip013.wav: "Oh, oh, baby!" | WER: None
#   ✅ pd_001_male_40s_clip014.wav: "তুমি আবার টাকা চুরি করছ দেখছিস তুমি গলদ সব টাকা চুরি করছ অনে" | WER: None
#   ✅ pd_001_male_40s_clip015.wav: "[সঙ্গীতের সুর]" | WER: None
#   ✅ pd_001_male_40s_clip016.wav: "ভাই বনমাল খেলাম পোলা যদি বাপের সামনে মারে সিস দেয় বাপ তো বন" | WER: None
#   ✅ pd_001_male_40s_clip017.wav: "দাদা এটা যদি তোমার দাদা হয় তাহলে এটা তোমার কি হয় মামি মামি" | WER: None
#   ✅ pd_001_male_40s_clip018.wav: "জাগা যা তোর নানির কলে ঘুম লাড়াও লাড়াও বুকু ভাই ও" | WER: None
#   ✅ pd_001_male_40s_clip019.wav: "[সঙ্গীতের আওয়াজ]" | WER: None
#   ✅ pd_001_male_40s_clip020.wav: "[সত্যি কথা]" | WER: None
#   ✅ pd_001_male_40s_clip021.wav: "আপনি ছাঁচরাদের মত আমার পিছু পিছু কেন ঘুরেন আমি ছাঁচরাদের মতন" | WER: None
#   ✅ pd_001_male_40s_clip022.wav: "পিছিয়ে পিছিয়ে আর ঘুরব না পাশের পাশের পাশের ইবা কেন ঘুরবেন " | WER: None
#   ✅ pd_001_male_40s_clip023.wav: "আমি কিন্তু কাউকে ঘুরতে না করিনি ববি" | WER: None
#   ✅ pd_001_male_40s_clip024.wav: "বাবিকে আপনাদের হক্কে দিয়েছে হ তো চোখে চোখে তো ভাই জন মুখে ম" | WER: None
#   ✅ pd_001_male_40s_clip025.wav: "তখন তো আমরা এত বড় বাড়ী করি কি করবো ভাই ঐ বুড়ো বুড়ো তোর ভ" | WER: None
#   ✅ pd_001_male_40s_clip026.wav: "সব ভাল লাগে ওই ফেসফ্যাশানী গলা ভাল লাগে না রে বুকু আবার দিয়" | WER: None
#   ✅ pd_001_male_40s_clip027.wav: "Subscribe to our channel to watch the full video." | WER: None
#   ✅ pd_001_male_40s_clip028.wav: "এইমাত্র পাওয়া বাংলা খবর। Bangla News 23 Jan 2022 |Banglades" | WER: None
#   ✅ pd_001_male_40s_clip029.wav: "রাত কটা বাজে বাজে কটা প্রতিদিন রাতে ফ্রিজ এই কি এটা কি" | WER: None
#   ✅ pd_001_male_40s_clip030.wav: "এইটা কি আই বোন আই বোন সিগারেট খাও বাচ্চা মাতাল" | WER: None
#   ✅ pd_001_male_40s_clip031.wav: "একদম কুকুরপাখি বাড়ি থেকে বের করে দেব শহরের বাচ্চা" | WER: None
#   ✅ pd_001_male_40s_clip032.wav: "Subscribe to the channel and subscribe to the channel." | WER: None
#   ✅ pd_001_male_40s_clip033.wav: "কি ব্যাপার আজকে সামনে দাঁড়িয়ে আছেন যে হ্যাঁ প্রতিদিন তো ডা" | WER: None
#   ✅ pd_001_male_40s_clip034.wav: "হ্যাঁ দেহে তুমি কি বই পড়ো আই হ্যা দেখবো গো" | WER: None
#   ✅ pd_001_male_40s_clip035.wav: "Social science! Go to maths. You read a lot. Read so much. D" | WER: None
#   ✅ pd_001_male_40s_clip036.wav: "এই এত কিছু পড়তে পারবো না সরি সরি তাহলে সামসপুর খেলা অঙ্কু ক" | WER: None
#   ✅ pd_001_male_40s_clip037.wav: "শোন আবার বিশটা একের মালোয়া বাসা পাখা গালা মুটা গালা মুটা" | WER: None
#   ✅ pd_001_male_40s_clip038.wav: "বুঝো না একের একের সুগন্ধি মালতা কেঁথা" | WER: None
#   ✅ pd_001_male_40s_clip039.wav: "এই যে আমার সামনে হাইড্রেটেড যাইতেছে আমি কওভার পড়তে&nbsp;ছি " | WER: None
#   ✅ pd_001_male_40s_clip040.wav: "আমার মহল্লা এমন সুন্দর একের জিনিস আছে আর আমি আজকে দেখলাম নাম" | WER: None
#   ✅ pd_001_male_40s_clip041.wav: "আরে কোথায় যাচ্ছ আমারে চিনতে না কেন এই মহল্লা সহ পুরো ধুনীয়" | WER: None
#   ✅ pd_001_male_40s_clip042.wav: "ও চরি বুঝো না একের রাখে জ্যাগিয়া মারার জন্য আমি ক্রাশ খেয়ে" | WER: None
#   ✅ pd_001_male_40s_clip043.wav: "[শিরোনাম]" | WER: None
#   ✅ pd_001_male_40s_clip044.wav: "[শিরোনাম]" | WER: None
#   ✅ pd_001_male_40s_clip045.wav: "এইমাত্র পাওয়া বাংলা খবর। Bangla News 23 Jan 2022 | Banglade" | WER: None
#   ✅ pd_001_male_40s_clip046.wav: "বইটা ভালো লাগে বই তো এটাই ভালো লাগছে তোমার তো ঘুরবে আমার জিন" | WER: None
#   ✅ pd_001_male_40s_clip047.wav: "এইমাত্র পাওয়া বাংলা খবর। Bangla News 23 Jan 2022 |Banglades" | WER: None
#   ✅ pd_001_male_40s_clip048.wav: "এখন এইটা আমার লাগাও" | WER: None
#   ✅ pd_001_male_40s_clip049.wav: "বাবু সিগদার আখর আখর ভূজস না" | WER: None
#   ✅ pd_001_male_40s_clip050.wav: "আপনি স্যার বসুন আমি এখানে বসে আসি নাই" | WER: None
#   ✅ br_001_male_25s_clip001.wav: "[অ্যাডভান্সড গান]" | WER: None
#   ✅ br_001_male_25s_clip002.wav: "[অ্যাডভান্সড গান]" | WER: None
#   ✅ br_001_male_25s_clip003.wav: "ড্রাইভার কই আমার ব্যাগ নাম আইতে হবে না হ্যাঁ তারা ড্রাইভার ক" | WER: 0.7692307692307693
#   ✅ br_001_male_25s_clip004.wav: "আমার হোটেল কমলে এখানে নামিয়ে কেন আমি জানি না এই অবস্থান ট্য" | WER: 0.7941176470588235
#   ✅ br_001_male_25s_clip005.wav: "বাবলু মা বাবলু মা আমি তো কিছুই জানি না আমার হোটেলের অবস্থান " | WER: 0.825
#   ✅ br_001_male_25s_clip006.wav: "হ্যালো বাঙালি কি হয়েছে দেখো বাবু এই এয়ারপোর্ট থেকে গাড়িতে" | WER: 0.8
#   ✅ br_001_male_25s_clip007.wav: "হা হা হা হা হা হা হা হা হা হা হা হা হা হা হা হা হা হা হা হা " | WER: 7.28
#   ✅ br_001_male_25s_clip008.wav: "পৌঁছে দিয়েছে হোটেল হোটেলের টাকা দিয়ে দিয়েছে লোকজন ঝামেলা " | WER: 0.8979591836734694
#   ✅ br_001_male_25s_clip009.wav: "[অবশ্যই]" | WER: 1.0
#   ✅ br_001_male_25s_clip010.wav: "আপনি আগে কখনো থাইল্যান্ডে আসেননি বাবু এটা আমার প্রথম থাইল্যা" | WER: 0.7567567567567568
#   ✅ br_001_male_25s_clip011.wav: "হুঁ আমি যে জোরদা দিয়ে খেয়েছি তার নাম বজপুরি জোরদা আমি বজপু" | WER: 0.7142857142857143
#   ✅ br_001_male_25s_clip012.wav: "এই জোরদা একটা লটারি খেয়ে যাও থাইল্যান্ড যাও আমি এই জোরদাটা " | WER: 0.7352941176470589
#   ✅ br_001_male_25s_clip013.wav: "তোমার দাদী তো হ্যাঁ হ্যাঁ হ্যাঁ আপনি এখানে এসেছেন আপনি তো এখ" | WER: 0.8125
#   ✅ br_001_male_25s_clip014.wav: "কোথায় চাকরি করেন থাইল্যান্ডের পাটুরিয়ায় পাটুরিয়ায় কেউ ন" | WER: 0.5862068965517241
#   ✅ br_001_male_25s_clip015.wav: "জায়গাটার নাম পাটায়া সেইটা তো পাটুরিয়া বলেছিলাম পাটুরিয়া " | WER: 0.7857142857142857
#   ✅ br_001_male_25s_clip016.wav: "কি করে তোমার পোলার ফোন দিয়ে আসবে তোমার পোলার ফোন নিয়ে আসবে" | WER: 0.725
#   ✅ br_001_male_25s_clip017.wav: "বাবা ওটা সাইপ্রাস না ওটা সারপ্রাইজ এই যে ডিম আর কি বললে এই য" | WER: 0.7142857142857143
#   ✅ br_001_male_25s_clip018.wav: "I'm the one who gave this card to me in the package." | WER: 1.0
#   ✅ br_001_male_25s_clip019.wav: "পেয়েছে এই না অন্য যদি আমার বন্ধুর হোটেলে রাখতে পারি তাহলে ক" | WER: 0.6451612903225806
#   ✅ br_001_male_25s_clip020.wav: "এই যে হোটেলে পেকেজ এই হোটেলে তো আপনি থাকতে পারবেন না এখানে ত" | WER: 0.625
#   ✅ br_001_male_25s_clip021.wav: "আমি আসব না আমি না থাকলে ব্যাচেলরদের মধ্যে সমস্যা নেই আমরা থা" | WER: 0.7906976744186046
#   ✅ br_001_male_25s_clip022.wav: "না মানে এই যে হিজাবের উপর যে চোখের উপর দিয়ে দেখলেই বোঝা যায" | WER: 0.7674418604651163
#   ✅ br_001_male_25s_clip023.wav: "এই দেখলেই দেখলেই তুমি কুঁচকে উঠবে তুমি এইখানে থাকার কোন ইচ্ছ" | WER: 0.8
#   ✅ br_001_male_25s_clip024.wav: "হা হা হা হা হা হা হা হা হা হা হা হা হা হা হা হা হা হা হা হা " | WER: 6.594594594594595
#   ✅ br_001_male_25s_clip025.wav: "আছেই খাবো মানে সবই হ্যাপের মানেই আছেই হ্যাপের স্যুপ দেবে হ্য" | WER: 0.9285714285714286
#   ✅ br_001_male_25s_clip026.wav: "ওটাও হাফের ফিনকি হাফের ফিনকি হাফের ফিনকি হাফের ফিনকি হাফের ফ" | WER: 1.1
#   ✅ br_001_male_25s_clip027.wav: "নাকি দুধ চা পাওয়া যাবে হ্যাঁ হ্যাঁ হ্যাঁ কিন্তু ঐটা খাবো কি" | WER: 0.7941176470588235
#   ✅ br_001_male_25s_clip028.wav: "হ্যাঁ হ্যাঁ হ্যাঁ হ্যাঁ হ্যাঁ হ্যাঁ হ্যাঁ হ্যাঁ হ্যাঁ হ্যাঁ " | WER: 3.789473684210526
#   ✅ br_001_male_25s_clip029.wav: "তাহলে তাহলে তো হাফ দিয়ে দাও হ্যাঁ প্যাকেজে হোটেলে তো সব ফের" | WER: 0.9642857142857143
#   ✅ br_001_male_25s_clip030.wav: "হাফকুচ খাও বাবু খাও বাবু তুমিও একটু বেশি যাও তুমিও একটা ভালো" | WER: 0.7368421052631579
#   ✅ br_001_male_25s_clip031.wav: "আমার বাবার মত না আমার বাবা-মা এর মত আমি আমার দায়িত্ব না আমা" | WER: 0.7837837837837838
#   ✅ br_001_male_25s_clip032.wav: "[Music]" | WER: None
#   ✅ br_001_male_25s_clip033.wav: "হ্যাঁ বন্ধু আমার কি মেসেজ সেন্টারে আজকে যে গ্রাহক হয়েছে জীব" | WER: 0.8095238095238095
#   ✅ br_001_male_25s_clip034.wav: "নায়িকারা না হয় কিছু না কিছু করতে পারছে না তারা একটা কাজ কর" | WER: 0.8163265306122449
#   ✅ br_001_male_25s_clip035.wav: "খুশি করতে পারে না এই কয়দিন আগে একটা চাইনিজ রে একটুখানি আছে " | WER: 0.6086956521739131
#   ✅ br_001_male_25s_clip036.wav: "এই তুমি কামের মধ্যে ভিডিও কল করছ দেখো ও মেয়ে পিঠের কি দেখো " | WER: 0.6551724137931034
#   ✅ br_001_male_25s_clip037.wav: "এই থাইলাইটের পাতায় হোটেলের না দেখো তোর মা এরে আইয়া কি কি" | WER: 0.8518518518518519
#   ✅ br_001_male_25s_clip038.wav: "হুঁ, হুঁ, কও, তুই আগে হোটেলে এসো, এই যে হোটেলে উঠছি, এই যে উ" | WER: 0.7931034482758621
#   ✅ br_001_male_25s_clip039.wav: "তুমি হোটেলে থাকো দেখো আমার ভাইয়া থাইল্যান্ডে আছে সমস্যাটা ক" | WER: 0.7441860465116279
#   ✅ br_001_male_25s_clip040.wav: "হালাল আয় করি আমার বাবা যদি জানে আমি যদি এই ম্যাসেজ সেন্টারে" | WER: 0.8392857142857143
#   ✅ br_001_male_25s_clip041.wav: "হ্যাঁ সেটাও ঠিক কথা বলেছ বন্ধু আমার একটা বন্ধু আছে এই লোকাল " | WER: 0.7111111111111111
#   ✅ br_001_male_25s_clip042.wav: "Okay, okay, you manage. Okay, don't worry. You take care of " | WER: 0.972972972972973
#   ✅ br_001_male_25s_clip043.wav: "লভ বললো একটু পরেই হোটেল এ আসবে আমরা উঠবো কাকু ও কাকু হোটেল ক" | WER: 0.6086956521739131
#   ✅ br_001_male_25s_clip044.wav: "কিন্তু ভাড়া একটু বেশি আরে ভাড়া বেশি জিনিসটা তো সুন্দর নাকি" | WER: 0.5277777777777778
#   ✅ br_001_male_25s_clip045.wav: "খালি বিশ্রাম করলে খাওয়ার দরকার হবে না না খাবে না তোমার শাশু" | WER: 0.7
#   ✅ br_001_male_25s_clip046.wav: "আমরা তো বাংলা খাবার খাবো বাবু কথা বলছো তুমি একটা কাজ রাস্তা " | WER: 0.7222222222222222
#   ✅ br_001_male_25s_clip047.wav: "তোলা আয় একটু পরে দেখবো আহা না বাবু তোমার এই রাস্তাটা একটু প" | WER: 0.7441860465116279
#   ✅ br_001_male_25s_clip048.wav: "আমি বললাম আমি মালিককে ডেকে নিয়ে যাই আমি কোন হোটেলের ওয়েটার" | WER: 0.8157894736842105
#   ✅ br_001_male_25s_clip049.wav: "টাকার অভাব নেই এই যে খাবার অর্ডার করবে তিনগুণ দাম মনে রাখবে " | WER: 0.88
#   ✅ br_001_male_25s_clip050.wav: "আচ্ছা থাকবে দুইটা বল আমার কমিশন হ্যাঁ থাকব মাথায় থাকব মাথায" | WER: 0.65
#   ✅ sy_001_male_26s_clip001.wav: "আসসালামু আলাইকুম আশা করি আপনারা সবাই ভাল আছেন আমরা চ্যানেল স" | WER: None
#   ✅ sy_001_male_26s_clip002.wav: "আগামী শেষ পর্বে ইনশাল্লাহ আমরা খাওয়া দাওয়া নিয়ে আলোচনার ব" | WER: None
#   ✅ sy_001_male_26s_clip003.wav: "এটা খুবই গুরুত্বপূর্ণ আজকালের ফসলের পর্বতে আমরা চাই যে শরীরে" | WER: None
#   ✅ sy_001_male_26s_clip004.wav: "বুঝাই দিতাম যে খানি খালে আমাদের মুখে দিয়ে খানি হারালে খানি " | WER: None
#   ✅ sy_001_male_26s_clip005.wav: "মূল উদ্দেশ্য হল অল্প শক্তির শোষণ করা আর এটা আমরা খান খানে গল" | WER: None
#   ✅ sy_001_male_26s_clip006.wav: "এটা আমরা অযৌক্তিক হয় তাহলে যে কোন কিছু গলা গলাতে গেলে আমরা " | WER: None
#   ✅ sy_001_male_26s_clip007.wav: "মুখের লালা চাব যেটা আছে তার সাথে মিশিয়ে সেব দিয়ে সব খান দি" | WER: None
#   ✅ sy_001_male_26s_clip008.wav: "ফুরা গলায় না কিন্তু কিছু জিনিস এটা গলাতে শুরু করে অনেক মানু" | WER: None
#   ✅ sy_001_male_26s_clip009.wav: "কষ্ট হয় এর জন্য টেস্ট মিলে না মুখ গায়ে যায় মুখ অনেক ধরনের" | WER: None
#   ✅ sy_001_male_26s_clip010.wav: "সেব আমরা ও প্রিস্ক্রিপশনও দিয়া দিই কিন্তু আর্টিফিশিয়ালটা ক" | WER: None
#   ✅ sy_001_male_26s_clip011.wav: "অনোর মাঝে হুকায় দুই ফাইব একটায় লাগিয়া শ্বাসর আর ওবাইদি গি" | WER: None
#   ✅ sy_001_male_26s_clip012.wav: "বাতাস শ্বাসের রাস্তা দিয়ে যায় আর যখন আমরা খাচ্ছি খনির রাস্" | WER: None
#   ✅ sy_001_male_26s_clip013.wav: "আমরা বিন খাইলে কারণ অ অঙ্গের বেড়া লাগায় আর আমাদের শরীরলে চ" | WER: None
#   ✅ sy_001_male_26s_clip014.wav: "তেজায়ুক খানিটা খানির রাস্তা মুখে যায় আর এ ফাইভ যেটা এখন আট" | WER: None
#   ✅ sy_001_male_26s_clip015.wav: "চাপ দিয়ে খানিতে নিয়ে আমাদের অয়েল গ্যাস স্টাডম্যাট ফেট ফেট" | WER: None
#   ✅ sy_001_male_26s_clip016.wav: "সব খানির গলানি শুরু করে ফ্যাট এ চারে খুব শক্তিশালী এসিড হয় " | WER: None
#   ✅ sy_001_male_26s_clip017.wav: "বালা টিকে খানি অজম করার লাগে আ ইটারে ফুরা মিশা নিয়ো এসিডের " | WER: None
#   ✅ sy_001_male_26s_clip018.wav: "দুই size এর আছে, ফয়েলটা ছোটো size ও যায়, তো ছোটোটার মধ্যে " | WER: None
#   ✅ sy_001_male_26s_clip019.wav: "রক্ত দিয়ে নিয়ে যায় আমাদের শরীর ও যিকোনো দরকার রক্ত দিয়ে " | WER: None
#   ✅ sy_001_male_26s_clip020.wav: "লিভারে জিনিস হল চরে চর্বি অজম হারা লাগে আর অটায় কিছু জিনিস " | WER: None
#   ✅ sy_001_male_26s_clip021.wav: "আর সবহানি চুটোফাই বেদি যায় চুটো ইন্টার্স্টাইন যায় আর যত যা" | WER: None
#   ✅ sy_001_male_26s_clip022.wav: "Large intestine বড় size এর বড় আর ইনোজিয়া আমাদের পানি cont" | WER: None
#   ✅ sy_001_male_26s_clip023.wav: "শরীর জন্য খুবই জরুরি কিছু বেমার হতে পারে যে এই পানিটা কন্ট্র" | WER: None
#   ✅ sy_001_male_26s_clip024.wav: "আমরা দায়বদ্ধ আর যে জিনিসগুলো অযৌক্তিক বা যে জিনিসগুলো অপ্রয" | WER: None
#   ✅ sy_001_male_26s_clip025.wav: "একবারে মুক্তাকি ধরিয়া আমরা বাটমুড় রাস্তা পর্যন্ত একটা ফাইভ" | WER: None
#   ✅ sy_001_male_26s_clip026.wav: "এমলা খান দেখানোর উদ্দেশ্যটা কি তা ফয়েলা নাম্বার আমরা ফেটার " | WER: None
#   ✅ sy_001_male_26s_clip027.wav: "আমরা অনেক সময় যখন ফেটো আড় দিয়ে থাকি আমরা আস্তা খান দেখাই " | WER: None
#   ✅ sy_001_male_26s_clip028.wav: "খানি যে কেন গিয়া ফরে যময় আর অজময় ওই দেখো আতর বাউসাইডেদি ছ" | WER: None
#   ✅ sy_001_male_26s_clip029.wav: "তবে ফরসে বুকিং নেই সে আস্তে আস্তে গানো নাই আর আর ওখান থেকেই " | WER: None
#   ✅ sy_001_male_26s_clip030.wav: "আর আমরা যতটা চর্বি বালিশ খাই ততটাই আমরা চর্বি ফুলে এবং অতিরি" | WER: None
#   ✅ sy_001_male_26s_clip031.wav: "বোল্টারে অর্ধেক বালি বালি বালির সাথে মিশিয়ে আমরা ঝাঁকুনি দি" | WER: None
#   ✅ sy_001_male_26s_clip032.wav: "ত্রিকমলা খান আমাদের ফেটের খসলানির জেগে রাখা জরুরি আর আর একটা" | WER: None
#   ✅ sy_001_male_26s_clip033.wav: "তো অনেক সময় আমরা যখন অতিরিক্ত খাচ্ছি অনেক সময় বলে যে খাওয়" | WER: None
#   ✅ sy_001_male_26s_clip034.wav: "আর ফ্যাট ফুরা বুকে যে খান দিয়ে আমরা যদি ফ্যাটটা ফুলে ফেলাই " | WER: None
#   ✅ sy_001_male_26s_clip035.wav: "এর প্রধান অসুবিধা হচ্ছে খানতা আমাদের শ্বাসের জন্য বেশি গুরুত" | WER: None
#   ✅ sy_001_male_26s_clip036.wav: "যদি আমরা শ্বাস না নিই আমরা অজ্ঞান হয়ে যাই পাঁচ মিনিট বাদে আ" | WER: None
#   ✅ sy_001_male_26s_clip037.wav: "অতলাগি শ্বাসলগি জায়গা রাখবা আমরা যখন খাই যাতে আমরা ফ্যাক্টর" | WER: None
#   ✅ sy_001_male_26s_clip038.wav: "আর আরও একটা জিনিস যে বলেছিলাম আমরা খানি খাই আর এক ফাইভ বেদি " | WER: None
#   ✅ sy_001_male_26s_clip039.wav: "শেষ পর্যন্ত খানিটা যেতে হবে আমরা সব খানিটা সব অযৌক্তিক তাই আ" | WER: None
#   ✅ sy_001_male_26s_clip040.wav: "পেটের মধ্যেই রয়ে যাবে এমন কোন নেই আমাদের এফ আই ডিজাইজারি সি" | WER: None
#   ✅ sy_001_male_26s_clip041.wav: "শরীরের যদি কোনো প্রয়োজন নাই, ইটারে আমরা শরীরে ইটারে চর্বি ব" | WER: None
#   ✅ sy_001_male_26s_clip042.wav: "সার্বভৌমত্বের উদ্দেশ্য যে যদি দরকার লাগে শরীরটা যদি উশাহ থাক" | WER: None
#   ✅ sy_001_male_26s_clip043.wav: "শরীরের উশাহ মানে চব্বিশ ঘন্টা চব্বিশ ঘন্টা যদি সে কিছু না খা" | WER: None
#   ✅ sy_001_male_26s_clip044.wav: "খানি আছে যে সে চব্বিশ ঘন্টা উশাহ নিচ্ছে ঘুম না, তো এ প্রযোজন" | WER: None
#   ✅ sy_001_male_26s_clip045.wav: "যাতে আমরা এক্সারসাইজ করি কি খাম খাম আটা খাম করে মাংস খামের স" | WER: None
#   ✅ sy_001_male_26s_clip046.wav: "চর্বির জ্বালানি শুরু হবে শক্তির জন্য আমাদের দেশের যে ডায়েট " | WER: None
#   ✅ sy_001_male_26s_clip047.wav: "জমি খাঁজ হবে দান হবে আট দিনের মধ্যে তারা গামিয়া এই শক্তি গু" | WER: None
#   ✅ sy_001_male_26s_clip048.wav: "জীবনও আমরা এমনিতে এখন কখনো খাম করি না তারা লঘু পরিশ্রম করে ন" | WER: None
#   ✅ sy_001_male_26s_clip049.wav: "আর এই সর্বিসের মাধ্যমে আমরা আজকালকেও অনেক রোগের কারণ সর্বিসে" | WER: None
#   ✅ sy_001_male_26s_clip050.wav: "শরীরের রোগ অকল করে ব্লক করতে পারে কি শাখা বাঁধিয়ে যেতে পারে" | WER: None
#   ✅ nb_001_male_30s_clip001.wav: "Welcome to Health Today, we are going to talk about the topi" | WER: 1.2
#   ✅ nb_001_male_30s_clip002.wav: "হারনিয়া বিভিন্ন ধরনের হয় হর্নিয়া শব্দটির মূল অর্থ গোদাবাং" | WER: 0.5454545454545454
#   ✅ nb_001_male_30s_clip003.wav: "পেটের নাড়ী বা অন্ত্রের বাইরে বেরিয়ে আসা, এটাকে বলা হয় হার" | WER: 0.5714285714285714
#   ✅ nb_001_male_30s_clip004.wav: "বিভিন্ন জায়গায় এই ফুটোর উপস্থিতি যদি দেখা যায়, কুঙ্কির কা" | WER: 0.5666666666666667
#   ✅ nb_001_male_30s_clip005.wav: "যদি দেখা যায় নাভীর বা আম্বিলিকসের মধ্য দিয়ে ফুটো আর সেটা দ" | WER: 0.38461538461538464
#   ✅ nb_001_male_30s_clip006.wav: "সাধারণত যে কোন ধরনের অপারেশনের পর পেটের অপারেশন বা সিজার হিস" | WER: 0.6
#   ✅ nb_001_male_30s_clip007.wav: "এইরকম সারা শরীরে অজস্র জায়গায় হারনিয়া হতে পারে, Commonly " | WER: 0.5
#   ✅ nb_001_male_30s_clip008.wav: "হার্নিয়া যে জায়গাতেই হোক, ট্রিটমেন্ট কিন্তু একটাই, অপারেশন" | WER: 0.3333333333333333
#   ✅ nb_001_male_30s_clip009.wav: "তাই যে মুহুর্তে হারনিয়া ধরা পড়ে সেই মুহুর্তে একজন অভিজ্ঞ স" | WER: 0.5909090909090909
#   ✅ nb_001_male_30s_clip010.wav: "এর প্রথম কারণ হচ্ছে হেভি ওয়েট লিফটিং বা ভারী জিনিস তোলা, তা" | WER: 0.5217391304347826
#   ✅ nb_001_male_30s_clip011.wav: "ভারী জিনিস তুলে নেওয়া, প্রি-ইস্টিং উড থেকে বের করে নেওয়া আ" | WER: 0.5652173913043478
#   ✅ nb_001_male_30s_clip012.wav: "প্রস্টেটের সমস্যার জন্য প্রশস্ত প্রসার যার জন্য বারবার পেটের" | WER: 0.5333333333333333
#   ✅ nb_001_male_30s_clip013.wav: "হারনিয়া তৈরি করে হারনিয়া তৈরির মূল কারণ হচ্ছে ইনট্রাবডমিনা" | WER: 0.78125
#   ✅ nb_001_male_30s_clip014.wav: "তার চিকিৎসা হচ্ছে হার্নিওপ্লাস্টি। হার্নিওপ্লাস্টি বিভিন্নভা" | WER: 0.7407407407407407
#   ✅ nb_001_male_30s_clip015.wav: "শরীরের যে কোন জায়গায় হর্নই হোক না কেন, আমাদের অপারেশনের উদ" | WER: 0.5714285714285714
#   ✅ nb_001_male_30s_clip016.wav: "জালিয়াতি করা কাজটি ওপেন অপারেশনের মাধ্যমে হতে পারে অথবা মাই" | WER: 0.7333333333333333
#   ✅ nb_001_male_30s_clip017.wav: "ফুটো করে পেটের ভিতর থেকে বা বাইরে থেকে জাল লাগানো হয় এবং পে" | WER: 0.5
#   ✅ nb_001_male_30s_clip018.wav: "জালিয়াতি বসিয়ে হারনিয়া রিপিয়ার করলে দেখা যায় হারনিয়া ফ" | WER: 0.3333333333333333
#   ✅ nb_001_male_30s_clip019.wav: "অনেকেই দেখেন হারনিয়া হয়েছে কিন্তু কোন অসুবিধা হচ্ছে না বলে" | WER: 0.4642857142857143
#   ✅ nb_001_male_30s_clip020.wav: "কিন্তু যে মুহুর্তে হঠাৎ করেই নড়াচড়া করতে বা কাঁপতে গিয়ে ভ" | WER: 0.6176470588235294
#   ✅ nb_001_male_30s_clip021.wav: "কিন্তু তখন রোগীর জীবন-মৃত্যু সমস্যা দেখা দেয়, এই সমস্যায় ন" | WER: 0.5666666666666667
#   ✅ nb_001_male_30s_clip022.wav: "Emergency operation outcome is always worse than planned ope" | WER: 0.9230769230769231
#   ✅ nb_001_male_30s_clip023.wav: "সেক্ষেত্রে অপারেশনের খরচ অনেক বেড়ে যায়, রোগীর ভুগার সম্ভাব" | WER: 0.5
#   ✅ nb_001_male_30s_clip024.wav: "ওপেন বা মাইক্রো সার্জারির মাধ্যমে হার্নিয়া অপারেশন করিয়ে স" | WER: 0.5625
#   ✅ nb_002_male_50s_clip001.wav: "Subscribe to the channel and subscribe to the channel." | WER: 4.5
#   ✅ nb_002_male_50s_clip002.wav: "স্ট্রোকের ক্ষেত্রে কিছু রিস্ক ফ্যাক্টর আছে যে যে কারণগুলো থা" | WER: 0.3157894736842105
#   ✅ nb_002_male_50s_clip003.wav: "কারণ এখানে একটা বা দুটি নির্দিষ্ট কারণ আমরা সনাক্ত করতে পারব" | WER: 0.34375
#   ✅ nb_002_male_50s_clip004.wav: "কারো যদি উচ্চ রক্তচাপ থাকে তাহলে তার রক্তক্ষরণ বা স্কেভিস্ট্" | WER: 0.30434782608695654
#   ✅ nb_002_male_50s_clip005.wav: "কোলেস্টেরল বা চর্বির পরিমাণ বাড়লে তার রক্তক্ষরণের পরিমাণ বা" | WER: 0.5652173913043478
#   ✅ nb_002_male_50s_clip006.wav: "ওবেসিটি যাদের বিএমআই ৩৯-৩৯ এর বেশি আছে তাদের রক্তক্ষরণ অথবা " | WER: 0.5
#   ✅ nb_002_male_50s_clip007.wav: "ডায়াবেটিস এটা একটা খুবই গুরুত্বপূর্ণ রিস্ক ফ্যাক্টর বা কারণ" | WER: 0.17391304347826086
#   ✅ nb_002_male_50s_clip008.wav: "হার্টের অসুখ যাদের থাকে হার্টের ভলভোলার ডিজিজ, রিউমেটিক ফিভা" | WER: 0.52
#   ✅ nb_002_male_50s_clip009.wav: "এতে হার্টের যে রীডম থাকে বা হার্টের যে রেট থাকে তা অনিয়মিত " | WER: 0.43333333333333335
#   ✅ nb_002_male_50s_clip010.wav: "কোন রক্তনালীকে ব্লক করে দেয় এটাও হয়, এছাড়াও আমাদের যে মেজ" | WER: 0.34782608695652173
#   ✅ nb_002_male_50s_clip011.wav: "এথেরাস স্ক্লোরোসিস বলে মেডিকেল টার্মে এগুলো, ফ্যাট কখনো কখনো" | WER: 0.4583333333333333
#   ✅ nb_002_male_50s_clip012.wav: "তাই এটা হচ্ছে মস্তিষ্কের কিছু স্ট্রোকের ঝুঁকি বা কারণ যাকে আ" | WER: 0.64
#   ✅ nb_002_male_50s_clip013.wav: "এটাকে আমরা নিয়ন্ত্রণ করতে পারি, ডায়াবেটিস এটাকে আমরা নিয়ন" | WER: 0.4782608695652174
#   ✅ nb_002_male_50s_clip014.wav: "Smoking is another important thing, we can control it. These" | WER: 0.896551724137931
#   ✅ nb_002_male_50s_clip015.wav: "যেমন পুরুষদের নারীদের চেয়ে স্ট্রোকের সম্ভাবনা বেশি, এই ক্ষে" | WER: 0.6190476190476191
#   ✅ nb_002_male_50s_clip016.wav: "তারপর কিছু রিস্ক ফ্যাক্টর আছে যেগুলো সাদাদের তুলনায় কালোদের" | WER: 0.39285714285714285
#   ✅ nb_002_male_50s_clip017.wav: "If my parents have family history or if other family members" | WER: 0.9629629629629629
#   ✅ nb_002_male_50s_clip018.wav: "এজন্য এগুলোকে বলা হয় নন-মডিফাইড রিস্ক ফ্যাক্টর বা কিছু রোগ " | WER: 0.625
#   ✅ nb_002_male_50s_clip019.wav: "যেগুলোতে রক্তনালীতে রক্ত জমা হওয়ার প্রবণতা বাড়তে থাকে, সেগ" | WER: 0.5294117647058824
#   ✅ nb_002_male_50s_clip020.wav: "ননমোডিফাইবল বা অপরিবর্তনীয় রিস্ক ফ্যাক্টর" | WER: 0.6666666666666666
#   ✅ nb_003_female_40s_clip001.wav: "সবই আসলে দোষ দেওয়া হয় মেয়েদের উপর যে তোমার বাচ্চা হচ্ছে ন" | WER: 0.5106382978723404
#   ✅ nb_003_female_40s_clip002.wav: "গাইনোকোলজিস্টের কাছে গেলে নাকি জন্মনিয়ন্ত্রণ পিল এটা কি সত্" | WER: 0.673469387755102
#   ✅ nb_003_female_40s_clip003.wav: "এটাকে আমরা বলি 'ডিজিজ অফ টিন' (Disease of unusual hair) আমরা" | WER: 0.6458333333333334
#   ✅ nb_003_female_40s_clip004.wav: "ডিসঅর্ডার, হরমোন ডিসঅর্ডার বা পিসিও এই সমস্যাগুলো আজকাল প্রা" | WER: 0.5142857142857142
#   ✅ nb_003_female_40s_clip005.wav: "আজকের এপিসোডটা প্রত্যেক বাংলাদেশী নারীর জন্য কারণ মেয়েদের স" | WER: 0.6071428571428571
#   ✅ nb_003_female_40s_clip006.wav: "প্রফেসর ডক্টর সেলিন আফতারের সাথে বাচ্চাদের আগে ডেলিভারি করে " | WER: 0.6111111111111112
#   ✅ ib_001_male_50s_clip001.wav: "স্বাস্থ্য সংক্রান্ত ভয় বা শরীরের ভয় সাধারণ মানুষ যারা আজ এ" | WER: 0.43902439024390244
#   ✅ ib_001_male_50s_clip002.wav: "মানে এটা নয় যে আমি সাথে সাথে একটা ঔষধ খেতে হবে কিন্তু যদি আ" | WER: 0.68
#   ✅ ib_001_male_50s_clip003.wav: "এটা নষ্ট হয়ে গেছে তুমি দেখবে খাবারের মধ্যে লেখা আছে এত ক্যা" | WER: 0.5116279069767442
#   ✅ ib_001_male_50s_clip004.wav: "ক্ষুধার্ত হলে তুমি খাবে ক্ষুধার্ত না হলে তুমি খাবে না যে জ্ঞ" | WER: 0.8
#   ✅ ib_001_male_50s_clip005.wav: "আজকে আমাদের সঙ্গে আছেন ড. সমীর কুমার ধারা" | WER: 0.4
#   ✅ ib_001_male_50s_clip006.wav: "আমরা আজকে কি বিষয়ে কথা বলব বা কি নিয়ে কথা বলব তার একটা ঝলক" | WER: 0.4
#   ✅ ib_001_male_50s_clip007.wav: "আজকের এই কথোপকথন, আমাদের কথা, এই কথা যে আমরা কি করতে চাই বা " | WER: 0.625
#   ✅ ib_001_male_50s_clip008.wav: "আমি শুরুতে এটা দিয়ে শুরু করি যে আজকের এই কথোপকথনে মানুষ কি " | WER: 0.6756756756756757
#   ✅ ib_001_male_50s_clip009.wav: "কিন্তু তাদের একটা ভয়ানক ভয় থাকে যদি কেউ ক্যান্সারে আক্রান্" | WER: 0.5625
#   ✅ ib_001_male_50s_clip010.wav: "যে রাতে কিছু একটা ঘটবে তাড়াতাড়ি হাসপাতালে ঢুকতে হবে কিন্তু" | WER: 0.6857142857142857
#   ✅ ib_001_male_50s_clip011.wav: "তাই এই ভয়, স্বাস্থ্য সম্পর্কিত ভয় বা শরীরের সাথে সম্পর্কিত" | WER: 0.45161290322580644
#   ✅ ib_001_male_50s_clip012.wav: "স্ট্রোক আর কারও হবে না আমার হবে না আমার হবে না হার্ট অ্যাটাক" | WER: 0.5952380952380952
#   ✅ ib_001_male_50s_clip013.wav: "এখন বলা হচ্ছে না যে সম্প্রতি কোভিডের টিকা দেওয়ার পর বা হার্" | WER: 0.7674418604651163
#   ✅ ib_001_male_50s_clip014.wav: "এর মধ্যে কিন্তু মানুষের হার্ট অ্যাটাকের মানে আমরা এটা সামলাত" | WER: 0.7209302325581395
#   ✅ ib_001_male_50s_clip015.wav: "মানে ওই ফেস্টে আমরা কি করেছি, প্রচুর খাবার খেয়েছি, ডিম, মাছ" | WER: 0.4411764705882353
#   ✅ ib_001_male_50s_clip016.wav: "এটাই কাজ হয়েছে তারপর যখন কোভিড শুরু হলো তখন আমাদের প্রতিদিন" | WER: 0.5625
#   ✅ ib_001_male_50s_clip017.wav: "ঘুমের অভ্যাস বেশি হয়ে গেছে স্বাভাবিকভাবেই প্রত্যেক মানুষ কি" | WER: 0.6857142857142857
#   ✅ ib_001_male_50s_clip018.wav: "সাথে সাথে তাদের হার্ট অ্যাটাক ক্যান্সার আলসার সাথে যে ভয়াবহ" | WER: 0.7073170731707317
#   ✅ ib_001_male_50s_clip019.wav: "কিন্তু কেউ দেখছে না, কেউ ঠিকনা দিচ্ছে না, এটাই আসল সমস্যা..." | WER: 0.7
#   ✅ ib_001_male_50s_clip020.wav: "এই ভয়টা মানুষের মধ্যে কি আগে থেকেই ছিল নাকি রেসেন্টলি এটা আ" | WER: 0.22727272727272727
#   ✅ ib_001_male_50s_clip021.wav: "আগে একটা মানুষের লড়াই ছিল রুটি কাপড় মোখা মানে আমার খাওয়া " | WER: 0.35
#   ✅ ib_001_male_50s_clip022.wav: "এখন কিন্তু মানুষের রুটি কাপড়ের মকানের লড়াই নয়, এখন তার লড" | WER: 0.3333333333333333
#   ✅ ib_001_male_50s_clip023.wav: "এই আকাঙ্ক্ষা থেকে কিন্তু তার ভয় তৈরি হয়েছে কারণ তার কাছে ক" | WER: 0.3939393939393939
#   ✅ ib_001_male_50s_clip024.wav: "যেমন দেশে, তাহলে সেই দেশে তাদের ভয় ফ্যাক্টর আমার হার্ট অ্যা" | WER: 0.4444444444444444
#   ✅ ib_001_male_50s_clip025.wav: "অথবা এই ভয়টা আরও বাড়ছে এবং দেখা যাচ্ছে যে এটা একটা বড় ব্য" | WER: 0.53125
#   ✅ ib_001_male_50s_clip026.wav: "তারাও দেখতে পাচ্ছে হঠাৎ করে একটা ব্যবসা বেড়েছে কারণ আমরা যদ" | WER: 0.5277777777777778
#   ✅ ib_001_male_50s_clip027.wav: "আর তারা সেবা দিতে পারে না সবসময়ই পূর্ণ কারণ এই ভয় মানুষকে " | WER: 0.7096774193548387
#   ✅ ib_001_male_50s_clip028.wav: "বারবার চেষ্টা করে দেখছি একবার পরীক্ষা করে দেখছি কোন সমস্যা ন" | WER: 0.8536585365853658
#   ✅ ib_001_male_50s_clip029.wav: "কিন্তু এই চিন্তা তাকে বারবার অসুস্থ করে তোলে, এই চিন্তা থেকে" | WER: 0.5357142857142857
#   ✅ ib_001_male_50s_clip030.wav: "কিন্তু সেখান থেকে মানুষের সেই জিনিসটি প্রতিষ্ঠিত হতে শুরু কর" | WER: 0.6216216216216216
#   ✅ ib_001_male_50s_clip031.wav: "আমার একদিন গ্যাসের জন্য বুকের ব্যথা হয়েছিল মানে এটা নয় যে " | WER: 0.5208333333333334
#   ✅ ib_001_male_50s_clip032.wav: "তাই স্বাভাবিকভাবেই সকালে আমার চাপ একটু বেশি থাকবে আমি যদি সে" | WER: 0.6938775510204082
#   ✅ ib_001_male_50s_clip033.wav: "কিন্তু আমি চাপের সমস্যাকে দূর করে দিয়েছি। এই জিনিসটি তৈরি ক" | WER: 0.76
#   ✅ ib_001_male_50s_clip034.wav: "কিভাবে মানুষ সুস্থ থাকতে পারে, যখন সে এই জ্ঞান পাবে তখন সে জ" | WER: 0.6052631578947368
#   ✅ ib_001_male_50s_clip035.wav: "তাহলে আমার সমস্যা সমাধান হবে তাহলে এটা আমাকে অবাক করে দিতে হ" | WER: 0.7608695652173914
#   ✅ ib_001_male_50s_clip036.wav: "#হম মানে আপনি বলছেন যে মানসিকভাবে আমরা অনেক বেশি অসুস্থতার ব" | WER: 0.45454545454545453
#   ✅ ib_001_male_50s_clip037.wav: "একটা পরিবেশ তৈরি করেছে যেটা সবসময়ই এমন একটা পরিবেশ তৈরি করে" | WER: 0.7352941176470589
#   ✅ ib_001_male_50s_clip038.wav: "তাহলে আরেকটা বিষয় আছে যারা সামাজিকভাবে অর্থনৈতিকভাবে একটু ব" | WER: 0.3181818181818182
#   ✅ ib_001_male_50s_clip039.wav: "যারা সত্যিই প্রতিদিনের রুটি উপার্জন করে ঘুরে বেড়ায় তারা মন" | WER: 0.6538461538461539
#   ✅ ib_001_male_50s_clip040.wav: "তাহলে মানুষ কি ভাবছে মানুষ কি ভাবছে দুঃখ মানুষ কি ভাবছে কষ্ট" | WER: 0.5217391304347826
#   ✅ ib_001_male_50s_clip041.wav: "কিছু মানুষ কি করছে তারা একজন মানুষকে পঙ্গু বানাতে চেষ্টা করছ" | WER: 0.3783783783783784
#   ✅ ib_001_male_50s_clip042.wav: "তুমি তার পাশে থাকো, মানে কোথাও না কোথাও একজনকে অন্যের চাহিদা" | WER: 0.6333333333333333
#   ✅ ib_001_male_50s_clip043.wav: "একজন স্ত্রী অসুস্থ সবসময় কিন্তু অসুস্থ নয় স্বামীর ভালোবাসা" | WER: 0.6206896551724138
#   ✅ ib_001_male_50s_clip044.wav: "এই ভান যখন সত্যিই অসুস্থ হয়ে যায় তখন মানুষ বুঝতে পারে যে স" | WER: 0.6923076923076923
#   ✅ ib_001_male_50s_clip045.wav: "কারণ আপনি যে বলেন যে শহরের মানুষ বা যাদের বেশি টাকা আছে তাদে" | WER: 0.6578947368421053
#   ✅ ib_001_male_50s_clip046.wav: "কিন্তু তারা করোনার সময় কেউ মারা যায়নি কিন্তু যারা ছিল কলকা" | WER: 0.6
#   ✅ ib_001_male_50s_clip047.wav: "এই নির্ভরতা কিন্তু মানুষকে অসুস্থ করে তোলে যারা স্বাধীন কারণ" | WER: 0.39285714285714285
#   ✅ ib_001_male_50s_clip048.wav: "কারণ আমি যেভাবে বড় হয়েছি, আমার গ্রামের জীবন যেভাবে কাটিয়ে" | WER: 0.5757575757575758
#   ✅ ib_001_male_50s_clip049.wav: "তাহলে এই ছোট ছোট জিনিসগুলো আমাদের বাড়িতেই তৈরি হতো কারণ আমর" | WER: 0.6875
#   ✅ ib_001_male_50s_clip050.wav: "যার রক্তচাপ রক্তচাপের দাস তার মাথায় যদি এই মানসিকতা থাকে যে" | WER: 0.6744186046511628
# ✅ seamlessm4t complete.

# %% [markdown]
# ---
# ## Model 12 — Whisper Large V3
# **HuggingFace:** `openai/whisper-large-v3` | **Params:** 1.55B
#
# **FIX 2 applied:** `max_new_tokens=440`

# %%
run_whisper_model('whisper_large_v3', 'openai/whisper-large-v3',
                  test_files, is_large=True)
# Out:
# 🔄 Loading openai/whisper-large-v3...
#    ⚠️  Large model — ensure GPU has ≥12GB VRAM.
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/1259 [00:00<?, ?it/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# ⚠️  whisper_large_v3 failed: Input type (float) and bias type (c10::Half) should be the same

# %% [markdown]
# ---
# ## Final Evaluation — Load ALL Transcripts from Drive + Recalculate WER

# %%
import pandas as pd
os.makedirs(EVALUATION_DIR, exist_ok=True)

# All 12 model names exactly as used when saving transcripts
ALL_MODEL_NAMES = [
    'wav2vec2_xlsr_300m_bn',
    'wav2vec2_xlsr53_bn',
    'vakyansh_bn',
    'wav2vec2_xlsr_cv_bn',
    'whisper_small',
    'whisper_medium',
    'whisper_v3_turbo',
    'bengaliai_whisper',
    'bengaliai_regional',
    'mms',
    'seamlessm4t',
    'whisper_large_v3',
]

print('📂 Loading transcripts from Drive for all 12 models...')
print('   (Includes models skipped this session + models run fresh this session)')
print()

rows = []
model_file_counts = {}

for model_name in ALL_MODEL_NAMES:
    transcript_dir = os.path.join(MODEL_OUTPUTS_DIR, f'{model_name}_transcripts')

    if not os.path.exists(transcript_dir):
        print(f'  ❌ {model_name}: no transcript folder found — model never ran.')
        model_file_counts[model_name] = 0
        continue

    count = 0
    for t in test_files:
        txt_path = os.path.join(transcript_dir, t['filename'].replace('.wav', '.txt'))

        if not os.path.exists(txt_path):
            # Transcript file missing for this audio — mark as missing
            rows.append({
                'model':             model_name,
                'dialect':           t['dialect'],
                'filename':          t['filename'],
                'transcript_preview':'FILE_MISSING',
                'wer': None, 'cer': None, 'mer': None,
                'wil': None, 'wip': None, 'bleu': None,
            })
            continue

        # Read transcript from Drive
        with open(txt_path, 'r', encoding='utf-8') as f:
            transcript = f.read().strip()

        # Read reference transcript (now manually added to Drive)
        reference = t['reference']  # already loaded in Cell 4

        # Calculate metrics using the reference transcript
        m = calculate_metrics(reference, transcript)

        rows.append({
            'model':             model_name,
            'dialect':           t['dialect'],
            'filename':          t['filename'],
            'transcript_preview':transcript[:80],
            'wer':  m['wer'],
            'cer':  m['cer'],
            'mer':  m['mer'],
            'wil':  m['wil'],
            'wip':  m['wip'],
            'bleu': m['bleu'],
        })
        count += 1

    model_file_counts[model_name] = count
    refs_count = sum(1 for t in test_files if t['reference'])
    wer_possible = refs_count  # WER only calculated when reference exists
    print(f'  ✅ {model_name}: {count} transcripts loaded | '
          f'WER calculable for {wer_possible} files')

df = pd.DataFrame(rows)

# ── Save evaluation_scores.csv (overwrites old empty one) ────────────────────
eval_path = os.path.join(EVALUATION_DIR, 'evaluation_scores.csv')
df.to_csv(eval_path, index=False)
print(f'\n✅ Saved: {eval_path}')

# ── Save wer_scores.csv ───────────────────────────────────────────────────────
wer_path = os.path.join(EVALUATION_DIR, 'wer_scores.csv')
df.to_csv(wer_path, index=False)
print(f'✅ Saved: {wer_path}')

# ── Summary table ─────────────────────────────────────────────────────────────
print('\n=== Average Metrics per Model ===')
print('(lower WER/CER/MER = better | higher BLEU/WIP = better | None = no reference yet)')
numeric_cols = ['wer', 'cer', 'mer', 'wil', 'wip', 'bleu']
summary = df.groupby('model')[numeric_cols].mean()
print(summary.to_string())
# Out:
# 📂 Loading transcripts from Drive for all 12 models...
#    (Includes models skipped this session + models run fresh this session)
#
#   ❌ wav2vec2_xlsr_300m_bn: no transcript folder found — model never ran.
#   ✅ wav2vec2_xlsr53_bn: 250 transcripts loaded | WER calculable for 147 files
#   ✅ vakyansh_bn: 250 transcripts loaded | WER calculable for 147 files
#   ✅ wav2vec2_xlsr_cv_bn: 250 transcripts loaded | WER calculable for 147 files
#   ❌ whisper_small: no transcript folder found — model never ran.
#   ❌ whisper_medium: no transcript folder found — model never ran.
#   ❌ whisper_v3_turbo: no transcript folder found — model never ran.
#   ❌ bengaliai_whisper: no transcript folder found — model never ran.
#   ❌ bengaliai_regional: no transcript folder found — model never ran.
#   ✅ mms: 250 transcripts loaded | WER calculable for 147 files
#   ✅ seamlessm4t: 250 transcripts loaded | WER calculable for 147 files
#   ❌ whisper_large_v3: no transcript folder found — model never ran.
#
# ✅ Saved: /content/drive/MyDrive/CSE499_EHR_Project/02_Phase1_ASR/evaluation/evaluation_scores.csv
# ✅ Saved: /content/drive/MyDrive/CSE499_EHR_Project/02_Phase1_ASR/evaluation/wer_scores.csv
#
# === Average Metrics per Model ===
# (lower WER/CER/MER = better | higher BLEU/WIP = better | None = no reference yet)
#                           wer       cer       mer       wil       wip      bleu
# model
# mms                  0.556769  0.268736  0.544689  0.732696  0.267304  0.200254
# seamlessm4t          0.767943  0.521011  0.628483  0.800738  0.199262  0.123285
# vakyansh_bn          1.031003  1.937950  0.996826  0.999870  0.000130  0.001085
# wav2vec2_xlsr53_bn   1.002272  0.824533  0.999392  0.999966  0.000034  0.000183
# wav2vec2_xlsr_cv_bn  0.680803  0.436500  0.647349  0.780607  0.219393  0.166810

# %% [markdown]
# ---
# ## Dialect-Level Accuracy + Rebuild dialect_accuracy.csv
# Recreates the `dialect_accuracy.csv` that existed from your first run, now with real WER values.

# %%
# A transcript is 'correct' if WER < 0.3 (less than 30% word error)
WER_THRESHOLD = 0.3

dialect_rows = []
for model_name in df['model'].unique():
    model_df = df[df['model'] == model_name].copy()
    row = {'model': model_name}
    overall_correct = 0
    overall_total   = 0
    for dialect in DIALECT_FOLDERS:
        d_df = model_df[model_df['dialect'] == dialect]
        # Only count files where WER was calculable (reference exists)
        has_wer  = d_df['wer'].notna()
        correct  = (d_df.loc[has_wer, 'wer'] < WER_THRESHOLD).sum()
        total    = has_wer.sum()
        accuracy = round(correct / total, 3) if total > 0 else None
        row[dialect]       = accuracy
        row[f'{dialect}_correct'] = int(correct)
        row[f'{dialect}_total']   = int(total)
        overall_correct += correct
        overall_total   += total
    row['OVERALL'] = round(overall_correct / overall_total, 3) if overall_total > 0 else None
    dialect_rows.append(row)

dialect_df = pd.DataFrame(dialect_rows).set_index('model')

# Save — overwrites old empty dialect_accuracy.csv
dialect_acc_path = os.path.join(EVALUATION_DIR, 'dialect_accuracy.csv')
dialect_df.to_csv(dialect_acc_path)
print(f'✅ Saved: {dialect_acc_path}')

# Print clean view (just accuracy columns, no counts)
display_cols = DIALECT_FOLDERS + ['OVERALL']
print('\n=== Dialect-Level Soft Accuracy (WER < 0.3 = correct) ===')
print('(None = no reference transcripts for that dialect yet)')
print(dialect_df[display_cols].to_string())
# Out:
# ✅ Saved: /content/drive/MyDrive/CSE499_EHR_Project/02_Phase1_ASR/evaluation/dialect_accuracy.csv
#
# === Dialect-Level Soft Accuracy (WER < 0.3 = correct) ===
# (None = no reference transcripts for that dialect yet)
#                     puran_dhaka  barishal sylheti  normal_bangla  indian_bangla  OVERALL
# model
# wav2vec2_xlsr53_bn         None       0.0    None          0.000          0.000    0.000
# vakyansh_bn                None       0.0    None          0.000          0.000    0.000
# wav2vec2_xlsr_cv_bn        None       0.0    None          0.163          0.082    0.113
# mms                        None       0.0    None          0.122          0.160    0.096
# seamlessm4t                None       0.0    None          0.020          0.020    0.014

# %% [markdown]
# ---
# ## ⚠️ Reference Transcript Check

# %%
print('📋 Reference transcript check:')
print(f'   Expected folder: {MANUAL_TRANSCRIPTS_DIR}')
print()

total_found = 0
for dialect in DIALECT_FOLDERS:
    dialect_ref_dir = os.path.join(MANUAL_TRANSCRIPTS_DIR, dialect)
    if not os.path.exists(dialect_ref_dir):
        print(f'  ❌ {dialect}: folder does not exist → {dialect_ref_dir}')
        continue
    txt_files = [f for f in os.listdir(dialect_ref_dir) if f.endswith('.txt')]
    total_found += len(txt_files)
    print(f'  {"✅" if len(txt_files) > 0 else "⚠️ "} {dialect}: {len(txt_files)} reference .txt files found')

print(f'\n  Total references found: {total_found}')
if total_found == 0:
    print('  ❌ No references found at all. Check your folder path.')
    print(f'  Expected: {MANUAL_TRANSCRIPTS_DIR}/[dialect]/[audio_name].txt')
    print('  Example:  .../manual/barishal/br_001_male_25s_clip001.txt')
elif total_found < 250:
    print(f'  ⚠️  Only {total_found}/250 references found. WER will be None for missing ones.')
else:
    print(f'  ✅ All 250 reference files found. Full WER calculation possible.')
# Out:
# 📋 Reference transcript check:
#    Expected folder: /content/drive/MyDrive/CSE499_EHR_Project/01_Dataset/transcripts/manual
#
#   ✅ puran_dhaka: 44 reference .txt files found
#   ✅ barishal: 50 reference .txt files found
#   ✅ sylheti: 50 reference .txt files found
#   ✅ normal_bangla: 50 reference .txt files found
#   ✅ indian_bangla: 50 reference .txt files found
#
#   Total references found: 244
#   ⚠️  Only 244/250 references found. WER will be None for missing ones.

# %% [markdown]
# ---
# ## ✅ Complete
#
# **What was updated in Google Drive:**
#
# | File | Location | What changed |
# |------|----------|--------------|
# | `evaluation_scores.csv` | `02_Phase1_ASR/evaluation/` | models, WER now filled in |
# | `wer_scores.csv` | `02_Phase1_ASR/evaluation/` | Same as above |
# | `dialect_accuracy.csv` | `02_Phase1_ASR/evaluation/` | Accuracy per dialect now filled in |
# | New transcript folders | `02_Phase1_ASR/model_outputs/` | From models that were fixed and ran fresh |
#
#
#
# **Models that were skipped (already ran) but WER is now calculated:**
# - `wav2vec2_xlsr53_bn`, `vakyansh_bn`, `wav2vec2_xlsr_cv_bn`, `mms` — transcripts loaded from Drive
